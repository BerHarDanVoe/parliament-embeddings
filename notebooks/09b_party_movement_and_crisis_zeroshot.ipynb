# %% [markdown]
# # Tracking Political Change with Embeddings of Parliamentary Speeches
# ***
# # Party Movement, Crisis Response and Positions — zero-shot topics
#
# This notebook covers the same analysis as notebook 6, but with zero-shot topics instead of topics assigned by BERTopic:
#
# 1. **Party-level analysis**: what the party-year embeddings look like before any topic filtering.
# 2. **Analyze trajectories**: do the political events show up as movement
#    in the embedding space? / Detect movement of parties triggered by crisis
# 3. **Party anchors**: where an axis can be
#    anchored, where do the parties sit?
# 4. **Topic frequencies**: does an event change how much is said about its topics at all?
#
# Topic assignments here come from the **zero-shot categories** of `05b_topic__analysis_zeroshot`
# (`speech_topic_assignments_zeroshot.csv`), not from the BERTopic clusters of `05`. The categories are
# coarse — 21 committee-style areas covering every speech — so each event rests on a much broader slice of
# the corpus than in the BERTopic twin, and the two notebooks are not expected to agree.

# %% [markdown]
# ## 0. Setup and data

# %%
import warnings; warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity
from aggregation_functions import aggregate_by_mp_year, aggregate_by_party_year
from adjustText import adjust_text
from matplotlib.ticker import MaxNLocator

# %%
TOPICS     = "speech_topic_assignments_zeroshot.csv"          # speech -> topic, from notebook 05b
SPEECHES   = "jina_v3_contrastive_full.parquet"   # one row per speech, fine-tuned encoder
PARTY_YEAR = "party_year_embeddings_finetuned.parquet"   # party-year aggregates, from notebook 03

# one colour map for the whole notebook
PARTY_COLORS = {
    "CDU/CSU":      "#151518",
    "SPD":          "#E3000F",
    "Grüne":        "#46962B",
    "FDP":          "#FFD700",
    "AfD":          "#009EE0",
    "LINKE":        "#BE3075",
    "PDS":          "#8B4789",
    "Fraktionslos": "#AAAAAA",
}
party_colors = PARTY_COLORS   # parts 1 and 2 refer to it in lowercase

# figure styling, set once so every figure in the notebook looks the same
plt.rcParams.update({"figure.dpi": 120, "axes.grid": True, "grid.alpha": 0.25,
                     "axes.spines.top": False, "axes.spines.right": False})

# %%
# data frame with speech to topic assignments
df_topics = pd.read_csv(TOPICS)
df_topics
# Out:
#        speaker_id    party  speech_id  topic_emb_raw  \
# 0        11001434      SPD     604683             14
# 1        11002754  CDU/CSU     604883             11
# 2        11000431      SPD     604885             11
# 3        11001180      FDP     604905             10
# 4        11003216  CDU/CSU     605067             10
# ...           ...      ...        ...            ...
# 82442    11004381      SPD    1060945             19
# 82443    11004854  CDU/CSU    1060947             18
# 82444    11004802      SPD    1060949             18
# 82445    11004802      SPD    1060955             15
# 82446    11004143  CDU/CSU    1060957             18
#
#                              topic_emb_raw_name  topic_emb_full  \
# 0      Umweltschutz, Klimapolitik und Atomkraft              14
# 1                   Bildung, Familie und Jugend              11
# 2                   Bildung, Familie und Jugend              11
# 3           Verteidigungspolitik und Bundeswehr              10
# 4           Verteidigungspolitik und Bundeswehr              10
# ...                                         ...             ...
# 82442                         Kultur und Medien              19
# 82443      Europapolitik und EU-Angelegenheiten              18
# 82444      Europapolitik und EU-Angelegenheiten              18
# 82445       Menschenrechte und humanitäre Hilfe              15
# 82446      Europapolitik und EU-Angelegenheiten              18
#
#                             topic_emb_full_name        date
# 0      Umweltschutz, Klimapolitik und Atomkraft  2000-01-19
# 1                   Bildung, Familie und Jugend  2000-01-20
# 2                   Bildung, Familie und Jugend  2000-01-20
# 3           Verteidigungspolitik und Bundeswehr  2000-01-20
# 4           Verteidigungspolitik und Bundeswehr  2000-01-21
# ...                                         ...         ...
# 82442                         Kultur und Medien  2021-05-07
# 82443      Europapolitik und EU-Angelegenheiten  2021-05-07
# 82444      Europapolitik und EU-Angelegenheiten  2021-05-07
# 82445       Menschenrechte und humanitäre Hilfe  2021-05-07
# 82446      Europapolitik und EU-Angelegenheiten  2021-05-07
#
# [82447 rows x 8 columns]

# %%
# data frame with fine tuned embeddings
df_embeddings = pd.read_parquet(SPEECHES)
df_embeddings
# Out:
#             id                                      speechContent  \
# 0       604683  Meine werten Kolleginnen und Kollegen! Liebe K...
# 1       604883  Rot-grün und Bildungsministerin Bulmahn sind w...
# 2       604885  Meine sehr verehrten Damen und Herren! Ich ste...
# 3       604905  Die aktuelle Lage der deutschen Werftindustrie...
# 4       605067  Verehrte Frau Wehrbeauftragte! Liebe Kolleginn...
# ...        ...                                                ...
# 82442  1060945  Es ist schon ein besonderer Treppenwitz, dass ...
# 82443  1060947  Verehrte Kolleginnen und Kollegen! Ich teile n...
# 82444  1060949  Jetzt fühle mich fast an „Blockwart“ erinnert,...
# 82445  1060955  Gut, ich beschränke mich auf einen Satz: Ich p...
# 82446  1060957  Vielen Dank. – Frau Präsidentin! Liebe Kollegi...
#
#        politicianId      politicianName  firstName    lastName  \
# 0          11001434  Christoph Matschie  Christoph    Matschie
# 1          11002754       thomas rachel     thomas      rachel
# 2          11000431       peter eckardt      peter     eckardt
# 3          11001180     jürgen koppelin     jürgen    koppelin
# 4          11003216       anita schäfer      anita     schäfer
# ...             ...                 ...        ...         ...
# 82442      11004381      Martin Rabanus     Martin     Rabanus
# 82443      11004854      Christoph Ploß  Christoph        Ploß
# 82444      11004802         Helge Lindh      Helge       Lindh
# 82445      11004802         Helge Lindh      Helge       Lindh
# 82446      11004143  Tankred Schipanski    Tankred  Schipanski
#
#               positionShort  factionId    party        date  year year_month  \
# 0      Member of Parliament         23      SPD  2000-01-19  2000    2000-01
# 1      Member of Parliament          4  CDU/CSU  2000-01-20  2000    2000-01
# 2      Member of Parliament         23      SPD  2000-01-20  2000    2000-01
# 3      Member of Parliament         13      FDP  2000-01-20  2000    2000-01
# 4      Member of Parliament          4  CDU/CSU  2000-01-21  2000    2000-01
# ...                     ...        ...      ...         ...   ...        ...
# 82442  Member of Parliament         23      SPD  2021-05-07  2021    2021-05
# 82443  Member of Parliament          4  CDU/CSU  2021-05-07  2021    2021-05
# 82444  Member of Parliament         23      SPD  2021-05-07  2021    2021-05
# 82445  Member of Parliament         23      SPD  2021-05-07  2021    2021-05
# 82446  Member of Parliament          4  CDU/CSU  2021-05-07  2021    2021-05
#
#        n_tokens  used_in_finetune  used_in_party_probe_val  \
# 0          1209             False                    False
# 1           988             False                    False
# 2          1087             False                    False
# 3          1550             False                    False
# 4          1552             False                    False
# ...         ...               ...                      ...
# 82442       991             False                    False
# 82443       943             False                    False
# 82444      1153             False                    False
# 82445       197             False                    False
# 82446      1073             False                    False
#
#        used_in_party_probe_test  used_finetuned_weights  \
# 0                         False                    True
# 1                         False                    True
# 2                         False                    True
# 3                         False                    True
# 4                         False                    True
# ...                         ...                     ...
# 82442                     False                    True
# 82443                     False                    True
# 82444                     False                    True
# 82445                     False                    True
# 82446                     False                    True
#
#                                                embedding
# 0      [0.03820973, -0.11824905, 0.035603546, -0.0051...
# 1      [0.043069527, -0.1234621, 0.08022803, 0.004297...
# 2      [0.03223048, -0.10839531, 0.07345019, -0.00229...
# 3      [0.057155393, -0.12872227, 0.027934263, -0.038...
# 4      [0.022645857, -0.14240317, 0.05878738, -0.0094...
# ...                                                  ...
# 82442  [0.106144175, -0.11403943, 0.059873722, 0.0198...
# 82443  [0.068563156, -0.08838378, 0.11244867, -0.0153...
# 82444  [0.10353798, -0.07043955, 0.06072252, 0.011076...
# 82445  [0.098100424, -0.12857388, 0.083329365, 0.0245...
# 82446  [0.123014644, -0.09370012, 0.08473621, -0.0053...
#
# [82447 rows x 18 columns]

# %%
# merge embedding and topics data frame
df_embeddings_topics = df_embeddings.merge(
    df_topics.drop(columns=["party", "date"]),
    left_on="id", right_on="speech_id",
    how="inner"
)

df_embeddings_topics = df_embeddings_topics[df_embeddings_topics.party != 'Fraktionslos']
df_embeddings_topics
# Out:
#             id                                      speechContent  \
# 0       604683  Meine werten Kolleginnen und Kollegen! Liebe K...
# 1       604883  Rot-grün und Bildungsministerin Bulmahn sind w...
# 2       604885  Meine sehr verehrten Damen und Herren! Ich ste...
# 3       604905  Die aktuelle Lage der deutschen Werftindustrie...
# 4       605067  Verehrte Frau Wehrbeauftragte! Liebe Kolleginn...
# ...        ...                                                ...
# 82442  1060945  Es ist schon ein besonderer Treppenwitz, dass ...
# 82443  1060947  Verehrte Kolleginnen und Kollegen! Ich teile n...
# 82444  1060949  Jetzt fühle mich fast an „Blockwart“ erinnert,...
# 82445  1060955  Gut, ich beschränke mich auf einen Satz: Ich p...
# 82446  1060957  Vielen Dank. – Frau Präsidentin! Liebe Kollegi...
#
#        politicianId      politicianName  firstName    lastName  \
# 0          11001434  Christoph Matschie  Christoph    Matschie
# 1          11002754       thomas rachel     thomas      rachel
# 2          11000431       peter eckardt      peter     eckardt
# 3          11001180     jürgen koppelin     jürgen    koppelin
# 4          11003216       anita schäfer      anita     schäfer
# ...             ...                 ...        ...         ...
# 82442      11004381      Martin Rabanus     Martin     Rabanus
# 82443      11004854      Christoph Ploß  Christoph        Ploß
# 82444      11004802         Helge Lindh      Helge       Lindh
# 82445      11004802         Helge Lindh      Helge       Lindh
# 82446      11004143  Tankred Schipanski    Tankred  Schipanski
#
#               positionShort  factionId    party        date  ...  \
# 0      Member of Parliament         23      SPD  2000-01-19  ...
# 1      Member of Parliament          4  CDU/CSU  2000-01-20  ...
# 2      Member of Parliament         23      SPD  2000-01-20  ...
# 3      Member of Parliament         13      FDP  2000-01-20  ...
# 4      Member of Parliament          4  CDU/CSU  2000-01-21  ...
# ...                     ...        ...      ...         ...  ...
# 82442  Member of Parliament         23      SPD  2021-05-07  ...
# 82443  Member of Parliament          4  CDU/CSU  2021-05-07  ...
# 82444  Member of Parliament         23      SPD  2021-05-07  ...
# 82445  Member of Parliament         23      SPD  2021-05-07  ...
# 82446  Member of Parliament          4  CDU/CSU  2021-05-07  ...
#
#        used_in_party_probe_val used_in_party_probe_test  \
# 0                        False                    False
# 1                        False                    False
# 2                        False                    False
# 3                        False                    False
# 4                        False                    False
# ...                        ...                      ...
# 82442                    False                    False
# 82443                    False                    False
# 82444                    False                    False
# 82445                    False                    False
# 82446                    False                    False
#
#        used_finetuned_weights  \
# 0                        True
# 1                        True
# 2                        True
# 3                        True
# 4                        True
# ...                       ...
# 82442                    True
# 82443                    True
# 82444                    True
# 82445                    True
# 82446                    True
#
#                                                embedding  speaker_id  \
# 0      [0.03820973, -0.11824905, 0.035603546, -0.0051...    11001434
# 1      [0.043069527, -0.1234621, 0.08022803, 0.004297...    11002754
# 2      [0.03223048, -0.10839531, 0.07345019, -0.00229...    11000431
# 3      [0.057155393, -0.12872227, 0.027934263, -0.038...    11001180
# 4      [0.022645857, -0.14240317, 0.05878738, -0.0094...    11003216
# ...                                                  ...         ...
# 82442  [0.106144175, -0.11403943, 0.059873722, 0.0198...    11004381
# 82443  [0.068563156, -0.08838378, 0.11244867, -0.0153...    11004854
# 82444  [0.10353798, -0.07043955, 0.06072252, 0.011076...    11004802
# 82445  [0.098100424, -0.12857388, 0.083329365, 0.0245...    11004802
# 82446  [0.123014644, -0.09370012, 0.08473621, -0.0053...    11004143
#
#        speech_id  topic_emb_raw                        topic_emb_raw_name  \
# 0         604683             14  Umweltschutz, Klimapolitik und Atomkraft
# 1         604883             11               Bildung, Familie und Jugend
# 2         604885             11               Bildung, Familie und Jugend
# 3         604905             10       Verteidigungspolitik und Bundeswehr
# 4         605067             10       Verteidigungspolitik und Bundeswehr
# ...          ...            ...                                       ...
# 82442    1060945             19                         Kultur und Medien
# 82443    1060947             18      Europapolitik und EU-Angelegenheiten
# 82444    1060949             18      Europapolitik und EU-Angelegenheiten
# 82445    1060955             15       Menschenrechte und humanitäre Hilfe
# 82446    1060957             18      Europapolitik und EU-Angelegenheiten
#
#        topic_emb_full                       topic_emb_full_name
# 0                  14  Umweltschutz, Klimapolitik und Atomkraft
# 1                  11               Bildung, Familie und Jugend
# 2                  11               Bildung, Familie und Jugend
# 3                  10       Verteidigungspolitik und Bundeswehr
# 4                  10       Verteidigungspolitik und Bundeswehr
# ...               ...                                       ...
# 82442              19                         Kultur und Medien
# 82443              18      Europapolitik und EU-Angelegenheiten
# 82444              18      Europapolitik und EU-Angelegenheiten
# 82445              15       Menschenrechte und humanitäre Hilfe
# 82446              18      Europapolitik und EU-Angelegenheiten
#
# [81916 rows x 24 columns]

# %% [markdown]
# The anchored-position and frequency analysis in parts 3 and 4 works on the same merged table, only in a
# slightly different shape: the placeholder speaker id `-1` is dropped and the embedding is kept as
# a float32 array in the column `E`.

# %%
df = df_embeddings_topics[df_embeddings_topics.politicianId != -1].copy()
df["E"] = df.embedding.map(lambda v: np.asarray(v, dtype="float32"))

ALL_TOPICS = sorted(df.topic_emb_full_name.unique())
print(f"{len(df):,} speeches | {len(ALL_TOPICS)} topics | years {df.year.min()}-{df.year.max()}")
print(df.party.value_counts().to_string())
# Out:
# 81,916 speeches | 21 topics | years 2000-2021
# party
# CDU/CSU    24032
# SPD        18064
# Grüne      14868
# LINKE      10836
# FDP        10381
# AfD         2638
# PDS         1097

# %% [markdown]
# ## 1. Party-level analysis
#
# As this part doesn't depent on topics, we don't repeat it and refert to notebook 6

# %% [markdown]
# ## 2. Analyze Trajectories
#
# We test if the following political events appear as detectable movements in the embedding space
# (embeddings aggregated by MP and year):
#
# - 9/11 terror attacks
# - Lehman Brothers collapse / global financial crisis
# - Fukushima nuclear disaster
# - Shift to migration scepticism in Germany (post-Cologne NYE)
#
# ### 2.1 Filter data
#
# To test, whether those events trigger movements of the embeddings, we first have to filter for
# related topics. The four `TOPICS_*` lists defined below are the single topic–event assignment used
# by the rest of the notebook — part 4 builds its `EVENTS` list from exactly these lists.

# %%
# List of all topics
print(df_embeddings_topics.topic_emb_full_name.unique())
# Out:
# ['Umweltschutz, Klimapolitik und Atomkraft' 'Bildung, Familie und Jugend'
#  'Verteidigungspolitik und Bundeswehr' 'Verkehr und Infrastruktur'
#  'Gesundheitspolitik und Krankenversicherung'
#  'Landwirtschaft und Ernährung' 'Steuern und Finanzpolitik'
#  'Europapolitik und EU-Angelegenheiten' 'Wohnungspolitik und Städtebau'
#  'Wirtschaftspolitik und Energieversorgung'
#  'Menschenrechte und humanitäre Hilfe'
#  'Außenpolitik und internationale Beziehungen'
#  'Arbeitsmarkt und Sozialpolitik' 'Innere Sicherheit und Polizei'
#  'Recht und Verbraucherschutz' 'Kultur und Medien'
#  'Migration, Asyl und Einwanderung' 'Forschung, Technologie und Raumfahrt'
#  'Sport und Ehrenamt' 'Bundeshaushalt und öffentliche Ausgaben'
#  'Entwicklungszusammenarbeit']

# %% [markdown]
# #### 9/11 terror attacks
# Zero-shot category related to the 9/11 terror attacks:
# - 'Verteidigungspolitik und Bundeswehr' ("defence policy / Bundeswehr") — the corpus records the
#   parliamentary consequences, the deployment mandates, rather than the attack itself.

# %%
TOPICS_9_11 = [
    'Verteidigungspolitik und Bundeswehr'
]

df_9_11 = df_embeddings_topics[df_embeddings_topics.topic_emb_raw_name.isin(TOPICS_9_11)]

df_9_11
# Out:
#             id                                      speechContent  \
# 3       604905  Die aktuelle Lage der deutschen Werftindustrie...
# 4       605067  Verehrte Frau Wehrbeauftragte! Liebe Kolleginn...
# 26      611164  Ich glaube, wir sollten versuchen, uns darüber...
# 46      616913  Verehrte Frau Präsidentin! Liebe Kolleginnen u...
# 53      604463  Herr Staatssekretär, stimmen Sie mit mir übere...
# ...        ...                                                ...
# 82425  1060880  Ich bin ganz irritiert, Herr Amthor, dass wir ...
# 82426  1060884  Die Bundeswehr befindet sich derzeit in zehn m...
# 82427  1060886  Vielen Dank. – Frau Präsidentin! Liebe Kollegi...
# 82428  1060890  Sehr verehrte Frau Präsidentin! Meine verehrte...
# 82429  1060892  In keinem anderen demokratischen Gemeinwesen a...
#
#        politicianId                 politicianName     firstName  \
# 3          11001180                jürgen koppelin        jürgen
# 4          11003216                  anita schäfer         anita
# 26         11002465              Gert Weisskirchen          Gert
# 46         11001451                  Markus Meckel        Markus
# 53         11000602                  Erich G Fritz       Erich G
# ...             ...                            ...           ...
# 82425      11004906  Marie-Agnes Strack-Zimmermann   Marie-Agnes
# 82426      11004361               Alexander S. Neu  Alexander S.
# 82427      11004217                 Tobias Lindner        Tobias
# 82428      11004256             Karl-Heinz Brunner    Karl-Heinz
# 82429      11004427                 Volker Ullrich        Volker
#
#                 lastName         positionShort  factionId    party  \
# 3               koppelin  Member of Parliament         13      FDP
# 4                schäfer  Member of Parliament          4  CDU/CSU
# 26          Weisskirchen  Member of Parliament         23      SPD
# 46                Meckel  Member of Parliament         23      SPD
# 53                 Fritz  Member of Parliament          4  CDU/CSU
# ...                  ...                   ...        ...      ...
# 82425  Strack-Zimmermann  Member of Parliament         13      FDP
# 82426                Neu  Member of Parliament          6    LINKE
# 82427            Lindner  Member of Parliament          3    Grüne
# 82428            Brunner  Member of Parliament         23      SPD
# 82429            Ullrich  Member of Parliament          4  CDU/CSU
#
#              date  ...  used_in_party_probe_val used_in_party_probe_test  \
# 3      2000-01-20  ...                    False                    False
# 4      2000-01-21  ...                    False                    False
# 26     2000-06-08  ...                    False                    False
# 46     2000-11-16  ...                    False                    False
# 53     2000-01-19  ...                    False                    False
# ...           ...  ...                      ...                      ...
# 82425  2021-05-07  ...                    False                    False
# 82426  2021-05-07  ...                    False                    False
# 82427  2021-05-07  ...                    False                    False
# 82428  2021-05-07  ...                    False                    False
# 82429  2021-05-07  ...                    False                    False
#
#        used_finetuned_weights  \
# 3                        True
# 4                        True
# 26                       True
# 46                       True
# 53                       True
# ...                       ...
# 82425                    True
# 82426                    True
# 82427                    True
# 82428                    True
# 82429                    True
#
#                                                embedding  speaker_id  \
# 3      [0.057155393, -0.12872227, 0.027934263, -0.038...    11001180
# 4      [0.022645857, -0.14240317, 0.05878738, -0.0094...    11003216
# 26     [0.10757694, -0.14154151, 0.052904192, -0.0188...    11002465
# 46     [0.12139425, -0.12524256, 0.046495404, 0.01839...    11001451
# 53     [0.107077464, -0.16449293, 0.08546085, 0.01843...    11000602
# ...                                                  ...         ...
# 82425  [0.039036125, -0.13014202, 0.089285806, -0.015...    11004906
# 82426  [0.06730394, -0.1388349, 0.06838469, -0.022937...    11004361
# 82427  [0.062334526, -0.13549909, 0.094697885, 0.0023...    11004217
# 82428  [0.075418845, -0.1311105, 0.0935403, 0.0201109...    11004256
# 82429  [0.066060245, -0.13447958, 0.07498974, -0.0229...    11004427
#
#        speech_id  topic_emb_raw                   topic_emb_raw_name  \
# 3         604905             10  Verteidigungspolitik und Bundeswehr
# 4         605067             10  Verteidigungspolitik und Bundeswehr
# 26        611164             10  Verteidigungspolitik und Bundeswehr
# 46        616913             10  Verteidigungspolitik und Bundeswehr
# 53        604463             10  Verteidigungspolitik und Bundeswehr
# ...          ...            ...                                  ...
# 82425    1060880             10  Verteidigungspolitik und Bundeswehr
# 82426    1060884             10  Verteidigungspolitik und Bundeswehr
# 82427    1060886             10  Verteidigungspolitik und Bundeswehr
# 82428    1060890             10  Verteidigungspolitik und Bundeswehr
# 82429    1060892             10  Verteidigungspolitik und Bundeswehr
#
#        topic_emb_full                  topic_emb_full_name
# 3                  10  Verteidigungspolitik und Bundeswehr
# 4                  10  Verteidigungspolitik und Bundeswehr
# 26                 10  Verteidigungspolitik und Bundeswehr
# 46                 10  Verteidigungspolitik und Bundeswehr
# 53                 10  Verteidigungspolitik und Bundeswehr
# ...               ...                                  ...
# 82425              10  Verteidigungspolitik und Bundeswehr
# 82426              10  Verteidigungspolitik und Bundeswehr
# 82427              10  Verteidigungspolitik und Bundeswehr
# 82428              10  Verteidigungspolitik und Bundeswehr
# 82429              10  Verteidigungspolitik und Bundeswehr
#
# [5461 rows x 24 columns]

# %% [markdown]
# #### Lehman Brothers collapse / global financial crisis
# Zero-shot category related to the Lehman Brothers collapse / global financial crisis:
# - 'Steuern und Finanzpolitik' ("taxes and financial policy")

# %%
TOPICS_FINANCE = [
    'Steuern und Finanzpolitik'
]

df_financial_crisis = df_embeddings_topics[df_embeddings_topics.topic_emb_full_name.isin(TOPICS_FINANCE)]
df_financial_crisis
# Out:
#             id                                      speechContent  \
# 9       606154  Kollege Brüderle, als Sie in Ihrer Rede Walter...
# 10      606144  Herr Kollege Glos, es ist in diesen Tagen wahr...
# 30      613688  Meine verehrten Kolleginnen und Kollegen! Am E...
# 81      604597  Frau Staatssekretärin, hat sich die Bundesregi...
# 94      604677  Herr Austermann, wenn ich Ihnen so zuhöre, dan...
# ...        ...                                                ...
# 82277  1060376  Einen Tusch für Herrn De Masi, für diesen typi...
# 82278  1060378  Wahlen sind eigentlich Feste der Demokratie, u...
# 82279  1060380  Geschätzte Kolleginnen und Kollegen! Das Thema...
# 82281  1060388  Nein, nicht aus der AfD-Fraktion. Danke schön....
# 82346  1060620  Vielen Dank für deinen Hinweis. – Herr Präside...
#
#        politicianId         politicianName       firstName   lastName  \
# 9          11003195  Klaus Wolfgang Müller  Klaus Wolfgang     Müller
# 10         11002108          Werner Schulz          Werner     Schulz
# 30         11000832       hansgeorg hauser       hansgeorg     hauser
# 81         11001955         Heinz Schemken           Heinz   Schemken
# 94         11003176         Reinhard Loske        Reinhard      Loske
# ...             ...                    ...             ...        ...
# 82277      11004778          Stefan Keuter          Stefan     Keuter
# 82278      11004258       Bernhard Daldrup        Bernhard    Daldrup
# 82279      11004815          Till Mansmann            Till   Mansmann
# 82281      11004710           Wiebke Esdar          Wiebke      Esdar
# 82346      11003834        Frank Schäffler           Frank  Schäffler
#
#               positionShort  factionId    party        date  ...  \
# 9      Member of Parliament          3    Grüne  2000-02-17  ...
# 10     Member of Parliament          3    Grüne  2000-02-17  ...
# 30     Member of Parliament          4  CDU/CSU  2000-09-15  ...
# 81     Member of Parliament          4  CDU/CSU  2000-01-19  ...
# 94     Member of Parliament          3    Grüne  2000-01-19  ...
# ...                     ...        ...      ...         ...  ...
# 82277  Member of Parliament          0      AfD  2021-05-06  ...
# 82278  Member of Parliament         23      SPD  2021-05-06  ...
# 82279  Member of Parliament         13      FDP  2021-05-06  ...
# 82281  Member of Parliament         23      SPD  2021-05-06  ...
# 82346  Member of Parliament         13      FDP  2021-05-06  ...
#
#        used_in_party_probe_val used_in_party_probe_test  \
# 9                        False                    False
# 10                       False                    False
# 30                       False                    False
# 81                       False                    False
# 94                       False                    False
# ...                        ...                      ...
# 82277                    False                    False
# 82278                    False                    False
# 82279                    False                    False
# 82281                    False                    False
# 82346                    False                    False
#
#        used_finetuned_weights  \
# 9                        True
# 10                       True
# 30                       True
# 81                       True
# 94                       True
# ...                       ...
# 82277                    True
# 82278                    True
# 82279                    True
# 82281                    True
# 82346                    True
#
#                                                embedding  speaker_id  \
# 9      [0.044166, -0.046673443, 0.020151215, -0.01457...    11003195
# 10     [0.084874205, -0.066379584, -0.008602232, -0.0...    11002108
# 30     [0.055651758, -0.046117816, 0.02309618, -0.001...    11000832
# 81     [0.08834104, -0.12370345, 0.007879714, 0.00902...    11001955
# 94     [0.044854026, -0.06649531, 0.027730538, 0.0186...    11003176
# ...                                                  ...         ...
# 82277  [0.07940369, -0.094734356, 0.013158427, -0.020...    11004778
# 82278  [0.054977946, -0.06534267, -0.00624483, -0.006...    11004258
# 82279  [0.08686029, -0.064966775, 0.03741426, 0.02124...    11004815
# 82281  [0.046059754, -0.0650443, 0.010508921, 0.00379...    11004710
# 82346  [0.0662791, -0.07967046, -0.016696166, 0.03175...    11003834
#
#        speech_id  topic_emb_raw         topic_emb_raw_name  topic_emb_full  \
# 9         606154              5  Steuern und Finanzpolitik               5
# 10        606144              5  Steuern und Finanzpolitik               5
# 30        613688              5  Steuern und Finanzpolitik               5
# 81        604597              5  Steuern und Finanzpolitik               5
# 94        604677              5  Steuern und Finanzpolitik               5
# ...          ...            ...                        ...             ...
# 82277    1060376              5  Steuern und Finanzpolitik               5
# 82278    1060378              5  Steuern und Finanzpolitik               5
# 82279    1060380              5  Steuern und Finanzpolitik               5
# 82281    1060388              5  Steuern und Finanzpolitik               5
# 82346    1060620              5  Steuern und Finanzpolitik               5
#
#              topic_emb_full_name
# 9      Steuern und Finanzpolitik
# 10     Steuern und Finanzpolitik
# 30     Steuern und Finanzpolitik
# 81     Steuern und Finanzpolitik
# 94     Steuern und Finanzpolitik
# ...                          ...
# 82277  Steuern und Finanzpolitik
# 82278  Steuern und Finanzpolitik
# 82279  Steuern und Finanzpolitik
# 82281  Steuern und Finanzpolitik
# 82346  Steuern und Finanzpolitik
#
# [6895 rows x 24 columns]

# %% [markdown]
# #### Fukushima nuclear disaster
# Zero-shot category related to the Fukushima nuclear disaster:
# - 'Umweltschutz, Klimapolitik und Atomkraft' ("environmental protection, climate policy and nuclear power")

# %%
TOPICS_FUKUSHIMA = [
    'Umweltschutz, Klimapolitik und Atomkraft'
]

df_fukushima = df_embeddings_topics[df_embeddings_topics.topic_emb_full_name.isin(TOPICS_FUKUSHIMA)]
df_fukushima
# Out:
#             id                                      speechContent  \
# 0       604683  Meine werten Kolleginnen und Kollegen! Liebe K...
# 13      607643  Liebe Damen und Herren von der Opposition, nac...
# 17      608502  Kolleginnen und Kollegen! Neben den erneuerbar...
# 18      609367  Wir beschäftigen uns heute mit zwei Beratungsg...
# 19      609369  Meine lieben Kolleginnen und Kollegen! „Lothar...
# ...        ...                                                ...
# 82418  1060842  Geschätzte Präsidentin! Werte Kollegen! Zunäch...
# 82419  1060852  Liebe Kollegin Schulze, ich habe eigentlich er...
# 82420  1060864  Liebe Annalena Baerbock! Wir waren ja gemeinsa...
# 82421  1060866  Ja, das Urteil des Bundesverfassungsgerichts i...
# 82422  1060868  Vielen Dank. – Frau Präsidentin! Liebe Kollegi...
#
#        politicianId      politicianName  firstName    lastName  \
# 0          11001434  Christoph Matschie  Christoph    Matschie
# 13         11003147    Winfried Hermann   Winfried     Hermann
# 17         11003201     Franz Obermeier      Franz   Obermeier
# 18         11002720        Steffi Lemke     Steffi       Lemke
# 19         11000851     Ulrich Heinrich     Ulrich    Heinrich
# ...             ...                 ...        ...         ...
# 82418      11004792        Rainer Kraft     Rainer       Kraft
# 82419      11003246      Jürgen Trittin     Jürgen     Trittin
# 82420      11004354       Klaus Mindrup      Klaus     Mindrup
# 82421      11004440     Anja Weisgerber       Anja  Weisgerber
# 82422      11003789        Jens Koeppen       Jens     Koeppen
#
#               positionShort  factionId    party        date  ...  \
# 0      Member of Parliament         23      SPD  2000-01-19  ...
# 13     Member of Parliament          3    Grüne  2000-03-16  ...
# 17     Member of Parliament          4  CDU/CSU  2000-03-24  ...
# 18     Member of Parliament          3    Grüne  2000-04-13  ...
# 19     Member of Parliament         13      FDP  2000-04-13  ...
# ...                     ...        ...      ...         ...  ...
# 82418  Member of Parliament          0      AfD  2021-05-07  ...
# 82419  Member of Parliament          3    Grüne  2021-05-07  ...
# 82420  Member of Parliament         23      SPD  2021-05-07  ...
# 82421  Member of Parliament          4  CDU/CSU  2021-05-07  ...
# 82422  Member of Parliament          4  CDU/CSU  2021-05-07  ...
#
#        used_in_party_probe_val used_in_party_probe_test  \
# 0                        False                    False
# 13                       False                    False
# 17                       False                    False
# 18                       False                    False
# 19                       False                    False
# ...                        ...                      ...
# 82418                    False                    False
# 82419                    False                    False
# 82420                    False                    False
# 82421                    False                    False
# 82422                    False                    False
#
#        used_finetuned_weights  \
# 0                        True
# 13                       True
# 17                       True
# 18                       True
# 19                       True
# ...                       ...
# 82418                    True
# 82419                    True
# 82420                    True
# 82421                    True
# 82422                    True
#
#                                                embedding  speaker_id  \
# 0      [0.03820973, -0.11824905, 0.035603546, -0.0051...    11001434
# 13     [0.07199013, -0.10530523, 0.06211386, -0.02565...    11003147
# 17     [0.06167038, -0.024343533, 0.015091101, 0.0007...    11003201
# 18     [0.08062443, -0.12149502, 0.040967006, -0.0155...    11002720
# 19     [0.058559496, -0.12589183, 0.076472685, -0.023...    11000851
# ...                                                  ...         ...
# 82418  [0.08162465, -0.10521896, 0.10528089, 0.001232...    11004792
# 82419  [0.043423418, -0.06840401, 0.009015245, -0.044...    11003246
# 82420  [0.044115603, -0.10372067, 0.00843534, -0.0140...    11004354
# 82421  [0.07935777, -0.07192968, 0.027810907, -0.0084...    11004440
# 82422  [0.060103845, -0.10402672, 0.03496311, -0.0168...    11003789
#
#        speech_id  topic_emb_raw                        topic_emb_raw_name  \
# 0         604683             14  Umweltschutz, Klimapolitik und Atomkraft
# 13        607643             14  Umweltschutz, Klimapolitik und Atomkraft
# 17        608502             14  Umweltschutz, Klimapolitik und Atomkraft
# 18        609367             14  Umweltschutz, Klimapolitik und Atomkraft
# 19        609369             14  Umweltschutz, Klimapolitik und Atomkraft
# ...          ...            ...                                       ...
# 82418    1060842             14  Umweltschutz, Klimapolitik und Atomkraft
# 82419    1060852             14  Umweltschutz, Klimapolitik und Atomkraft
# 82420    1060864             14  Umweltschutz, Klimapolitik und Atomkraft
# 82421    1060866             14  Umweltschutz, Klimapolitik und Atomkraft
# 82422    1060868             14  Umweltschutz, Klimapolitik und Atomkraft
#
#        topic_emb_full                       topic_emb_full_name
# 0                  14  Umweltschutz, Klimapolitik und Atomkraft
# 13                 14  Umweltschutz, Klimapolitik und Atomkraft
# 17                 14  Umweltschutz, Klimapolitik und Atomkraft
# 18                 14  Umweltschutz, Klimapolitik und Atomkraft
# 19                 14  Umweltschutz, Klimapolitik und Atomkraft
# ...               ...                                       ...
# 82418              14  Umweltschutz, Klimapolitik und Atomkraft
# 82419              14  Umweltschutz, Klimapolitik und Atomkraft
# 82420              14  Umweltschutz, Klimapolitik und Atomkraft
# 82421              14  Umweltschutz, Klimapolitik und Atomkraft
# 82422              14  Umweltschutz, Klimapolitik und Atomkraft
#
# [9711 rows x 24 columns]

# %% [markdown]
# #### Shift to migration scepticism in Germany (post-Cologne NYE)
# Zero-shot category related to the shift to migration scepticism (post-Cologne NYE):
# - 'Migration, Asyl und Einwanderung' ("migration, asylum and immigration")

# %%
TOPICS_MIGRATION = [
    'Migration, Asyl und Einwanderung'
]

df_migration = df_embeddings_topics[df_embeddings_topics.topic_emb_raw_name.isin(TOPICS_MIGRATION)]

df_migration
# Out:
#             id                                      speechContent  \
# 65      604526  Herr Staatssekretär, herzlichen Dank. Ich bin ...
# 356     605729  Ich freue mich, dass wir als Frauenpolitikerin...
# 357     605733  Eine vernünftige Regelung des § 19 des Ausländ...
# 360     605740  Der heute vorliegende Gesetzentwurf - daran be...
# 361     605744  Der vorliegende Gesetzentwurf ist nach der Ref...
# ...        ...                                                ...
# 81257  1057243  Ich will als Zusammenfassung der Debatte sagen...
# 81710  1058603  Werte Kollegen! Ich bin ein optimistischer Men...
# 81711  1058607  Ich wiederhole, was Herr Dr. Wirth gesagt hat ...
# 82057  1059657  Jetzt, in tiefer Nacht, weitet der vorliegende...
# 82058  1059659  Nach Jahrzehnten der Unsicherheit sollen nun a...
#
#        politicianId   politicianName  firstName   lastName  \
# 65         11003141   Norbert Hauser    Norbert     Hauser
# 356        11000513        ilse falk       ilse       falk
# 357        11002805      max stadler        max    stadler
# 360        11001023      ulla jelpke       ulla     jelpke
# 361        11003123   lilo friedrich       lilo  friedrich
# ...             ...              ...        ...        ...
# 81257      11004795   Michael Kuffer    Michael     Kuffer
# 81710      11004936  Christian Wirth  Christian      Wirth
# 81711      11004802      Helge Lindh      Helge      Lindh
# 82057      11004698  Gottfried Curio  Gottfried      Curio
# 82058      11004857      Filiz Polat      Filiz      Polat
#
#               positionShort  factionId    party        date  ...  \
# 65     Member of Parliament          4  CDU/CSU  2000-01-19  ...
# 356    Member of Parliament          4  CDU/CSU  2000-01-28  ...
# 357    Member of Parliament         13      FDP  2000-01-28  ...
# 360    Member of Parliament         22      PDS  2000-01-28  ...
# 361    Member of Parliament         23      SPD  2000-01-28  ...
# ...                     ...        ...      ...         ...  ...
# 81257  Member of Parliament          4  CDU/CSU  2021-03-24  ...
# 81710  Member of Parliament          0      AfD  2021-04-15  ...
# 81711  Member of Parliament         23      SPD  2021-04-15  ...
# 82057  Member of Parliament          0      AfD  2021-04-22  ...
# 82058  Member of Parliament          3    Grüne  2021-04-22  ...
#
#        used_in_party_probe_val used_in_party_probe_test  \
# 65                       False                    False
# 356                      False                    False
# 357                      False                    False
# 360                      False                    False
# 361                      False                    False
# ...                        ...                      ...
# 81257                    False                    False
# 81710                    False                    False
# 81711                    False                    False
# 82057                    False                    False
# 82058                    False                    False
#
#        used_finetuned_weights  \
# 65                       True
# 356                      True
# 357                      True
# 360                      True
# 361                      True
# ...                       ...
# 81257                    True
# 81710                    True
# 81711                    True
# 82057                    True
# 82058                    True
#
#                                                embedding  speaker_id  \
# 65     [0.060253546, -0.14832552, 0.0646142, 0.012922...    11003141
# 356    [-0.010461927, -0.08811033, 0.064029954, 0.041...    11000513
# 357    [0.0048696594, -0.104695745, 0.093123056, 0.05...    11002805
# 360    [-0.01133787, -0.10267522, 0.078751326, 0.0230...    11001023
# 361    [-0.0137834065, -0.10178208, 0.104098834, 0.02...    11003123
# ...                                                  ...         ...
# 81257  [0.019013926, -0.13724563, 0.09939637, 0.00655...    11004795
# 81710  [0.044358496, -0.15327023, 0.09969344, 0.02846...    11004936
# 81711  [0.0077297105, -0.12962928, 0.11264864, 0.0146...    11004802
# 82057  [0.04031125, -0.15821378, 0.099463485, 0.03978...    11004698
# 82058  [0.04472569, -0.14642842, 0.0954658, 0.0148422...    11004857
#
#        speech_id  topic_emb_raw                topic_emb_raw_name  \
# 65        604526              2  Migration, Asyl und Einwanderung
# 356       605729              2  Migration, Asyl und Einwanderung
# 357       605733              2  Migration, Asyl und Einwanderung
# 360       605740              2  Migration, Asyl und Einwanderung
# 361       605744              2  Migration, Asyl und Einwanderung
# ...          ...            ...                               ...
# 81257    1057243              2  Migration, Asyl und Einwanderung
# 81710    1058603              2  Migration, Asyl und Einwanderung
# 81711    1058607              2  Migration, Asyl und Einwanderung
# 82057    1059657              2  Migration, Asyl und Einwanderung
# 82058    1059659              2  Migration, Asyl und Einwanderung
#
#        topic_emb_full               topic_emb_full_name
# 65                  2  Migration, Asyl und Einwanderung
# 356                 2  Migration, Asyl und Einwanderung
# 357                 2  Migration, Asyl und Einwanderung
# 360                 2  Migration, Asyl und Einwanderung
# 361                 2  Migration, Asyl und Einwanderung
# ...               ...                               ...
# 81257               2  Migration, Asyl und Einwanderung
# 81710               2  Migration, Asyl und Einwanderung
# 81711               2  Migration, Asyl und Einwanderung
# 82057               2  Migration, Asyl und Einwanderung
# 82058               2  Migration, Asyl und Einwanderung
#
# [2534 rows x 24 columns]

# %% [markdown]
# ### 2.2 Plot trajectories
# We plot the party trajectories reduced to two dimensions via PCA in a single plot, restricted to the years around the event we want to detect, to keep the plot readable.

# %%
def plot_trajectory(df, year, timespan, topic, crisis):

    # restrict to the years around the event (to make plots more readable)
    df = df[(df["year"] >= timespan[0]) & (df["year"] <= timespan[1])]

    # aggregate the filtered embeddings by party and year
    df_agg = aggregate_by_party_year(df)

    # stack embeddings to array
    stack = np.stack(df_agg['embedding'])

    # PCA to reduce embedding space to two dimensions
    pca_traj = PCA(n_components=2)
    pcs_traj = pca_traj.fit_transform(stack)

    # data frame for plot
    df_party_trajectories = pd.DataFrame({
        "dim1": pcs_traj[:, 0],
        "dim2": pcs_traj[:, 1],
        "party": df_agg.party,
        "year": df_agg.year
    })

    df_party_trajectories = df_party_trajectories.sort_values(["party", "year"])

    fig, ax = plt.subplots()
    texts = []

    # plot trajectories
    for party, color in party_colors.items():
        subset = df_party_trajectories[df_party_trajectories["party"] == party]

        # skip parties with no speech in the event year itself
        if year not in subset["year"].values:
            continue

        # line stays faint, markers on top stay fully opaque
        ax.plot(subset["dim1"], subset["dim2"], color=color, label=party, alpha=0.3)
        ax.scatter(subset["dim1"], subset["dim2"], color=color, s=15, zorder=4)

        if len(subset) >= 2:
            ax.annotate('', xy=(subset["dim1"].iloc[1], subset["dim2"].iloc[1]),
                            xytext=(subset["dim1"].iloc[0], subset["dim2"].iloc[0]),
                            arrowprops=dict(arrowstyle='->', color=color, lw=2, alpha=0.3))

        # highlight the event year
        year_row = subset[subset["year"] == year]
        ax.scatter(year_row["dim1"], year_row["dim2"], color=color,
                   s=80, edgecolors="black", zorder=5)

        # collect the label for the event year, adjusted afterwards to avoid overlap
        texts.append(ax.text(year_row["dim1"].iloc[0], year_row["dim2"].iloc[0],
                             f"{year} ({crisis})", fontsize=8, color=color))

    adjust_text(texts, ax=ax)

    ax.legend(loc="lower right")
    ax.axis("off")
    ax.set_title(f"Trajectories of Party-Year Embeddings ({topic})")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Reading the trajectory plots.** Each panel runs its own PCA on the party-year embeddings of that
# topic and event window only, so the axes are not comparable between panels — only the shape of a path
# within one panel means anything. The large marker is the event year; parties with no speech in that
# year are skipped.

# %%
plot_trajectory(df_9_11, 2001, [2000, 2005], 'Terrorism', '9/11 terror attacks')

# %% [markdown]
# The parties fall into two loose groups (CDU/CSU, FDP and PDS above, SPD and Grüne below), but that is
# the PCA axis, not a political ordering. The 2001 markers sit in the middle of each path rather than at
# a turning point, and the steps before and after 2001 are of similar length — 9/11 does not show up as
# a jump in any party's defence-policy language.

# %%
plot_trajectory(df_financial_crisis, 2008, [2006, 2010], 'Financial Politics', 'Lehman Brothers collapse')

# %% [markdown]
# The 2008 markers don't show any alignment or division. CDU/CSU and SPD sit closer together while the LINKE is
# furthest away, which reflects the standing distance between government and opposition language rather
# than a crisis effect.

# %%
plot_trajectory(df_fukushima, 2011, [2009, 2013], 'Nuclear Energy', 'Fukushima nuclear disaster')

# %% [markdown]
# A clear cluster forms around the two governing parties (CDU/CSU and FDP), with the Grüne and LINKE both clearly separated from this cluster. The SPD makes a distinct move in 2009 — the year it switches from government to opposition — away from its former coalition partner CDU/CSU and toward the opposition party Grüne. The year 2011 itself does not change any of these clusters.

# %%
plot_trajectory(df_migration, 2016, [2013, 2019], 'Migration', 'Cologne NYE')

# %% [markdown]
# All four parties drift in the same direction across the window and end in the same upper-right corner —
# the shared era movement that PC1 shows below. The 2016 markers sit in the lower middle of every path,
# and the long steps are 2013→2014 and 2017→2018, not the ones around the event.

# %% [markdown]
# Since the trajectories in a single combined plot were hard to read, we split this up and create one 2D PCA trajectory plot per party instead, covering the party's full time range (not restricted to the event window).

# %%
def plot_trajectory_per_party(df, year, topic, crisis, timespan):

    # restrict to the years around the event, same as plot_trajectory,
    # so the PCA is fit on the same data and trajectories are comparable
    df = df[(df["year"] >= timespan[0]) & (df["year"] <= timespan[1])]

    # aggregate the filtered embeddings by party and year
    df_agg = aggregate_by_party_year(df)

    # stack embeddings to array
    stack = np.stack(df_agg['embedding'])

    # PCA to reduce embedding space to two dimensions (fit once, across all parties)
    pca_traj = PCA(n_components=2)
    pcs_traj = pca_traj.fit_transform(stack)

    # data frame for plot
    df_party_trajectories = pd.DataFrame({
        "dim1": pcs_traj[:, 0],
        "dim2": pcs_traj[:, 1],
        "party": df_agg.party,
        "year": df_agg.year
    })

    df_party_trajectories = df_party_trajectories.sort_values(["party", "year"])

    # one plot per party
    for party, color in party_colors.items():
        subset = df_party_trajectories[df_party_trajectories["party"] == party]

        # skip parties with no speech in the event year itself
        if year not in subset["year"].values:
            continue

        fig, ax = plt.subplots(figsize=(6, 5))

        # line between points stays faint, markers on top stay fully opaque
        ax.plot(subset["dim1"], subset["dim2"], color=color, alpha=0.3)
        ax.scatter(subset["dim1"], subset["dim2"], color=color, s=15, zorder=4)

        # arrows between all consecutive points, to show the full trajectory direction
        for i in range(len(subset) - 1):
            ax.annotate('', xy=(subset["dim1"].iloc[i+1], subset["dim2"].iloc[i+1]),
                            xytext=(subset["dim1"].iloc[i], subset["dim2"].iloc[i]),
                            arrowprops=dict(arrowstyle='->', color=color, lw=1.5, alpha=0.3))

        # collect labels for adjustText instead of placing them with a fixed offset
        texts = []
        for i in range(len(subset)):
            yr = subset["year"].iloc[i]
            label = f"{yr} ({crisis})" if yr == year else str(yr)
            texts.append(ax.text(subset["dim1"].iloc[i], subset["dim2"].iloc[i],
                                 label, fontsize=8, color=color))

        adjust_text(texts, ax=ax, arrowprops=dict(arrowstyle='-', color=color, lw=0.5))

        # highlight the event year
        year_row = subset[subset["year"] == year]
        ax.scatter(year_row["dim1"], year_row["dim2"], color=color,
                   s=80, edgecolors="black", zorder=5)

        ax.axis("off")
        ax.set_title(f"{party} — Trajectory of Year Embeddings ({topic})")
        plt.tight_layout()
        plt.show()

# %%
plot_trajectory_per_party(df_9_11, 2001, 'Terrorism', '9/11 terror attacks', [2000, 2005])

# %% [markdown]
# Looking at the individual parties gives a mixed picture: for some parties, 2001 marks a particularly large step, while for others it does not.

# %%
plot_trajectory_per_party(df_financial_crisis, 2008, 'Financial Politics', 'Lehman Brothers collapse', [2006, 2010])

# %% [markdown]
# For the centre-left parties, 2008 marks a particularly large step, while the movements for the FDP and CDU/CSU remain within the range of their usual step sizes.

# %%
plot_trajectory_per_party(df_fukushima, 2011, 'Nuclear Energy', 'Fukushima nuclear disaster', [2009, 2013])

# %% [markdown]
# The largest steps occur mainly in the year following the disaster, which is somewhat surprising given that it happened as early as March — one might expect its effects to already show up within the same year.

# %%
plot_trajectory_per_party(df_migration, 2016, 'Migration', 'Cologne NYE', [2013, 2019])

# %% [markdown]
# In every panel the 2015→2016 step is among the shortest, while 2013→2014 and 2017→2018 are the long
# ones.

# %% [markdown]
# To make the time axis easier to interpret, we reduce the embedding space to a single dimension (PC1) instead of two, and plot each party's PC1 value over the years directly, with the event year marked by a vertical line.

# %%
def plot_trajectory_1d(df, year, topic, crisis):

    # aggregate the embeddings by party and year
    df_agg = aggregate_by_party_year(df)

    # stack embeddings to array
    stack = np.stack(df_agg['embedding'])

    # PCA to reduce embedding space to one dimension
    pca_traj = PCA(n_components=1)
    pcs_traj = pca_traj.fit_transform(stack)

    # data frame for plot
    df_party_trajectories = pd.DataFrame({
        "pc1": pcs_traj[:, 0],
        "party": df_agg.party,
        "year": df_agg.year
    })

    df_party_trajectories = df_party_trajectories.sort_values(["party", "year"])

    fig, ax = plt.subplots()

    for party, color in party_colors.items():
        subset = df_party_trajectories[df_party_trajectories["party"] == party]

        # skip parties with no speech in the event year itself
        if year not in subset["year"].values:
            continue

        ax.plot(subset["year"], subset["pc1"], color=color, label=party, marker='o', markersize=3)

    # mark the event year and label it
    ax.axvline(year, color="grey", linestyle="--", linewidth=1)
    ax.annotate(crisis, (year, ax.get_ylim()[1]), xytext=(3, -10),
                textcoords="offset points", fontsize=8, color="0.2")

    # force integer year ticks
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))

    ax.set_xlabel("Year")
    ax.set_ylabel("PC1")
    ax.legend(loc="upper left", bbox_to_anchor=(1.02, 1))
    ax.set_title(f"PC1 of Party-Year Embeddings over Time ({topic})")
    plt.tight_layout()
    plt.show()

# %%
plot_trajectory_1d(df_9_11, 2001, 'Terrorism', '9/11 terror attacks')

# %% [markdown]
# PC1 rises steadily for every party, from about −0.10 in 2000 to about +0.10 in 2021, and no line breaks
# away in 2001. The parties stay within roughly 0.03 of each other for most of the period, so this axis
# is carrying the era rather than a party position.

# %%
plot_trajectory_1d(df_financial_crisis, 2008, 'Financial Politics', 'Lehman Brothers collapse')

# %% [markdown]
# The same picture: a common upward drift, with the 2008 line cutting through the middle of a smooth rise.
# The FDP's steep climb into 2017 is not a move but a gap — the party was out of parliament from 2013 to
# 2017, so the line simply connects across the missing years.

# %%
plot_trajectory_1d(df_fukushima, 2011, 'Nuclear Energy', 'Fukushima nuclear disaster')

# %% [markdown]
# Around 2011 the lines are flat and tightly bunched. The one conspicuous feature is between 2017 and
# 2019, when every party rises by roughly 0.1 at once — a shared movement, six years after Fukushima, and
# much more plausibly the climate debate than the disaster.

# %%
plot_trajectory_1d(df_migration, 2016, 'Migration', 'Cologne NYE')

# %% [markdown]
# A kink is rather visible for 2013 -> 2014 than for 2015 -> 2016

# %%
def demean_by_year(df_traj, value_col="pc1"):
    """Subtracts the across-party mean per year from the given value column."""
    df_traj = df_traj.copy()
    year_means = df_traj.groupby("year")[value_col].transform("mean")
    df_traj[f"{value_col}_demeaned"] = df_traj[value_col] - year_means
    return df_traj

# %% [markdown]
# To rule out that a shared, year-wide shift in language (rather than a party-specific move) is driving the pattern, we subtract each year's across-party mean from PC1 before plotting, so only each party's position relative to the others in that year remains.

# %%
def plot_trajectory_1d_demeaned(df, year, topic, crisis):

    # aggregate the embeddings by party and year
    df_agg = aggregate_by_party_year(df)

    # stack embeddings to array
    stack = np.stack(df_agg['embedding'])

    # PCA to reduce embedding space to one dimension
    pca_traj = PCA(n_components=1)
    pcs_traj = pca_traj.fit_transform(stack)

    # data frame for plot
    df_party_trajectories = pd.DataFrame({
        "pc1": pcs_traj[:, 0],
        "party": df_agg.party,
        "year": df_agg.year
    })

    df_party_trajectories = df_party_trajectories.sort_values(["party", "year"])

    # subtract the across-party mean per year (to remove common, year-wide shifts)
    df_party_trajectories = demean_by_year(df_party_trajectories, value_col="pc1")

    fig, ax = plt.subplots()

    for party, color in party_colors.items():
        subset = df_party_trajectories[df_party_trajectories["party"] == party]

        # skip parties with no speech in the event year itself
        if year not in subset["year"].values:
            continue

        ax.plot(subset["year"], subset["pc1_demeaned"], color=color, label=party, marker='o', markersize=3)

    # mark the event year and label it
    ax.axvline(year, color="grey", linestyle="--", linewidth=1)
    ax.annotate(crisis, (year, ax.get_ylim()[1]), xytext=(3, -10),
                textcoords="offset points", fontsize=8, color="0.2")

    # force integer year ticks
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))

    ax.set_xlabel("Year")
    ax.set_ylabel("PC1 (demeaned per year)")
    ax.legend(loc="upper left", bbox_to_anchor=(1.02, 1))
    ax.set_title(f"PC1 of Party-Year Embeddings over Time, Demeaned ({topic})")
    plt.tight_layout()
    plt.show()

# %%
plot_trajectory_1d_demeaned(df_9_11, 2001, "Terrorism", '9/11 terror attacks')

# %%
plot_trajectory_1d_demeaned(df_financial_crisis, 2008, "Financial Politics", 'Lehman Brothers collapse')

# %%
plot_trajectory_1d_demeaned(df_fukushima, 2011, "Nuclear Energy", 'Fukushima nuclear disaster')

# %%
plot_trajectory_1d_demeaned(df_migration, 2016, "Migration", 'Cologne NYE')

# %% [markdown]
# Subtracting each year's cross-party mean removes the common drift, but no event year produces a kink in any of the four panels.
# Whatever the events did, it is not visible as a party-specific move in PC1.

# %% [markdown]
# We therefore try two alternative approaches to the visual inspection of party trajectories:
# - instead of tracking whole parties, we focus on individual politicians who specialized in the respective topic
# - instead of relying on a visual check, we compute the cosine similarity between consecutive embeddings and look for peaks in the resulting distance, indicating unusually large shifts.

# %%
def find_specialist_per_party(data, topic_name, year):
    """
    For a given topic and year: pick the politician with the most speeches on
    this topic per party (including name), restricted to politicians who
    actually spoke on this topic in the given event year.
    """
    topic_speeches = data[data["topic_emb_raw_name"] == topic_name]

    # only politicians active on this topic in the event year itself qualify
    active_in_year = set(
        topic_speeches.loc[topic_speeches["year"] == year, "politicianId"]
    )
    topic_speeches = topic_speeches[topic_speeches["politicianId"].isin(active_in_year)]

    specialists = {}
    for party, group in topic_speeches.groupby("party"):
        top_politician = group["politicianId"].value_counts().idxmax()
        top_name = group.loc[group["politicianId"] == top_politician, "politicianName"].iloc[0]
        specialists[party] = {"politicianId": top_politician, "name": top_name}

    return specialists

# %%
# the first (main) topic of each event defines its specialists
specialists_9_11 = find_specialist_per_party(df_embeddings_topics, TOPICS_9_11[0], 2001)
specialists_finance = find_specialist_per_party(df_embeddings_topics, TOPICS_FINANCE[0], 2008)
specialists_nuclear_energy = find_specialist_per_party(df_embeddings_topics, TOPICS_FUKUSHIMA[0], 2011)
specialists_migration = find_specialist_per_party(df_embeddings_topics, TOPICS_MIGRATION[0], 2016)

# %%
def get_specialist_trajectories(data, specialists):
    """specialists: Dict {party: {"politicianId": ..., "name": ...}} aus find_specialist_per_party."""
    politician_ids = [s["politicianId"] for s in specialists.values()]
    id_to_name = {s["politicianId"]: s["name"] for s in specialists.values()}

    df_specialists = data[data["politicianId"].isin(politician_ids)]
    df_traj = aggregate_by_mp_year(df_specialists)
    df_traj["politicianName"] = df_traj["politicianId"].map(id_to_name)
    return df_traj

# %%
df_specialists_9_11 = get_specialist_trajectories(df_9_11, specialists_9_11)
df_specialists_9_11
# Out:
#     politicianId  year    party  n_speeches  \
# 0       11001180  2000      FDP          10
# 1       11001180  2001      FDP           7
# 2       11001180  2002      FDP           8
# 3       11001180  2003      FDP           4
# 4       11001180  2004      FDP           3
# ..           ...   ...      ...         ...
# 71      11003152  2001  CDU/CSU           1
# 72      11003152  2003  CDU/CSU           1
# 73      11003152  2018      AfD           4
# 74      11003152  2019      AfD           2
# 75      11003152  2020      AfD           2
#
#                                             embedding   politicianName
# 0   [0.07358741, -0.1478721, 0.06182598, -0.004762...  jürgen koppelin
# 1   [0.05750292, -0.14661483, 0.05039869, -0.02663...  jürgen koppelin
# 2   [0.06551809, -0.12836927, 0.046915743, 0.00552...  jürgen koppelin
# 3   [0.034806397, -0.14136173, 0.053461127, -0.003...  jürgen koppelin
# 4   [0.044266194, -0.15829138, 0.06370818, -0.0169...  jürgen koppelin
# ..                                                ...              ...
# 71  [0.0897924, -0.21167703, 0.021133704, -0.00063...   Martin Hohmann
# 72  [0.032130137, -0.17650822, 0.099275686, 0.0606...   Martin Hohmann
# 73  [0.049579278, -0.14987367, 0.055604815, -0.011...   Martin Hohmann
# 74  [0.040915832, -0.14791188, 0.070458874, -0.015...   Martin Hohmann
# 75  [0.06620547, -0.15557784, 0.049374785, -0.0090...   Martin Hohmann
#
# [76 rows x 6 columns]

# %%
df_specialists_finance = get_specialist_trajectories(df_financial_crisis, specialists_finance)
df_specialists_finance
# Out:
#     politicianId  year  party  n_speeches  \
# 0       11000921  2000    PDS           9
# 1       11000921  2001    PDS          10
# 2       11000921  2002    PDS           7
# 3       11000921  2005  LINKE           3
# 4       11000921  2006  LINKE          18
# ..           ...   ...    ...         ...
# 74      11003837  2014  Grüne           9
# 75      11003837  2015  Grüne          10
# 76      11003837  2016  Grüne          12
# 77      11003837  2017  Grüne           4
# 78      11003837  2018  Grüne           6
#
#                                             embedding  politicianName
# 0   [0.059650123, -0.0758905, 0.013587915, 0.00572...    barbara höll
# 1   [0.057292305, -0.07789811, 0.027127773, 0.0007...    barbara höll
# 2   [0.05736616, -0.090811156, 0.027597683, 0.0206...    barbara höll
# 3   [0.04872191, -0.05655377, 0.012152378, 0.02922...    barbara höll
# 4   [0.055395707, -0.07343403, 0.03379464, 0.01779...    barbara höll
# ..                                                ...             ...
# 74  [0.09067932, -0.06857446, -0.008261606, -0.007...  Gerhard Schick
# 75  [0.095024735, -0.076072596, -0.0015632908, -0....  Gerhard Schick
# 76  [0.09676173, -0.10487964, 0.015693285, -0.0080...  Gerhard Schick
# 77  [0.08913572, -0.07610387, 0.009087905, -0.0120...  Gerhard Schick
# 78  [0.09104246, -0.092294514, -0.012247741, -0.01...  Gerhard Schick
#
# [79 rows x 6 columns]

# %%
df_specialists_fukushima = get_specialist_trajectories(df_fukushima, specialists_nuclear_energy)
df_specialists_fukushima
# Out:
#     politicianId  year  party  n_speeches  \
# 0       11002636  2000    PDS          29
# 1       11002636  2001    PDS          12
# 2       11002636  2002    PDS          11
# 3       11002636  2005  LINKE           2
# 4       11002636  2006  LINKE          13
# ..           ...   ...    ...         ...
# 61      11004081  2017  Grüne          11
# 62      11004081  2018  Grüne          25
# 63      11004081  2019  Grüne          21
# 64      11004081  2020  Grüne          15
# 65      11004081  2021  Grüne           5
#
#                                             embedding        politicianName
# 0   [0.08071459, -0.11760782, 0.040602244, -0.0235...  eva bulling-schröter
# 1   [0.076447845, -0.116159834, 0.038874432, -0.02...  eva bulling-schröter
# 2   [0.07347641, -0.14299063, 0.046686534, -0.0322...  eva bulling-schröter
# 3   [0.0887623, -0.09703824, 0.046291158, -0.01623...  eva bulling-schröter
# 4   [0.06891127, -0.110709116, 0.04062388, -0.0259...  eva bulling-schröter
# ..                                                ...                   ...
# 61  [0.07380884, -0.14699942, 0.048076227, -0.0003...       Oliver Krischer
# 62  [0.046658736, -0.13916393, 0.03634237, -0.0121...       Oliver Krischer
# 63  [0.069318704, -0.12454128, 0.02777545, -0.0191...       Oliver Krischer
# 64  [0.07643287, -0.10392053, 0.028695293, -0.0266...       Oliver Krischer
# 65  [0.052568037, -0.12905326, 0.024358, -0.042243...       Oliver Krischer
#
# [66 rows x 6 columns]

# %%
df_specialists_migration = get_specialist_trajectories(df_migration, specialists_migration)
df_specialists_migration
# Out:
#     politicianId  year    party  n_speeches  \
# 0       11001023  2000      PDS           9
# 1       11001023  2001      PDS           4
# 2       11001023  2006    LINKE           4
# 3       11001023  2007    LINKE           6
# 4       11001023  2008    LINKE           3
# ..           ...   ...      ...         ...
# 57      11003589  2014  CDU/CSU           4
# 58      11003589  2015  CDU/CSU           7
# 59      11003589  2016  CDU/CSU          10
# 60      11003589  2017  CDU/CSU           5
# 61      11003589  2018  CDU/CSU           6
#
#                                             embedding politicianName
# 0   [0.026877591, -0.14642826, 0.080866024, 0.0143...    ulla jelpke
# 1   [0.020337688, -0.14675927, 0.081776455, 0.0125...    ulla jelpke
# 2   [0.0032662828, -0.13357493, 0.09007467, -0.007...    ulla jelpke
# 3   [0.028673554, -0.15130492, 0.09942752, 0.00795...    ulla jelpke
# 4   [0.044260785, -0.14676593, 0.07625618, 0.00824...    ulla jelpke
# ..                                                ...            ...
# 57  [0.029130582, -0.1232682, 0.09527607, 0.032753...  Stephan Mayer
# 58  [0.0360136, -0.14167008, 0.0953799, 0.03721262...  Stephan Mayer
# 59  [0.04955908, -0.13128056, 0.08646698, 0.020973...  Stephan Mayer
# 60  [0.03464604, -0.13882908, 0.09931757, 0.026321...  Stephan Mayer
# 61  [0.00959084, -0.11724839, 0.09863099, 0.030056...  Stephan Mayer
#
# [62 rows x 6 columns]

# %%
def plot_trajectory_1d_specialists(df, year, topic, crisis, specialists):
    df_agg = aggregate_by_mp_year(df)

    stack = np.stack(df_agg['embedding'])
    pca_traj = PCA(n_components=1)
    pcs_traj = pca_traj.fit_transform(stack)

    df_traj = pd.DataFrame({
        "pc1": pcs_traj[:, 0],
        "politicianId": df_agg.politicianId,
        "party": df_agg.party,
        "year": df_agg.year
    })
    df_traj = df_traj.sort_values(["politicianId", "year"])

    fig, ax = plt.subplots(figsize=(8, 5))

    for party, info in specialists.items():
        politician_id = info["politicianId"]
        name = info["name"]
        subset = df_traj[df_traj["politicianId"] == politician_id]

        # skip specialists with no speech in the event year itself
        if year not in subset["year"].values:
            continue

        # connecting line across all years, in the color of the party 
        ax.plot(subset["year"], subset["pc1"], color=party_colors[party],
                lw=1, alpha=0.8, zorder=2)

        # markers colored by the MP's ACTUAL party in that year, so a party
        # switch (e.g. PDS -> LINKE) is visible as a color change
        for actual_party, g in subset.groupby("party"):
            ax.scatter(g["year"], g["pc1"], color=party_colors.get(actual_party, "grey"),
                       s=20, zorder=3)

        # one legend entry per specialist, labeled by the party they were selected for
        ax.plot([], [], color=party_colors[party], marker='o', markersize=4,
                label=f"{party} ({name})")

    # mark the event year and label it
    ax.axvline(year, color="grey", linestyle="--", linewidth=1)
    ax.annotate(crisis, (year, ax.get_ylim()[1]), xytext=(3, -10),
                textcoords="offset points", fontsize=8, color="0.2")

    # force integer year ticks
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))

    ax.set_xlabel("Year")
    ax.set_ylabel("PC1")
    ax.legend(loc="upper left", bbox_to_anchor=(1.02, 1), fontsize=8)
    ax.set_title(f"PC1 of Specialist MP Embeddings over Time ({topic})")
    plt.tight_layout()
    plt.show()

# %%
plot_trajectory_1d_specialists(df_specialists_9_11, 2001, 'Terrorism', '9/11 terror attacks', specialists_9_11)

# %%
plot_trajectory_1d_specialists(df_specialists_finance, 2008, 'Financial Politics', 'Lehman Brothers collapse', specialists_finance)

# %%
plot_trajectory_1d_specialists(df_specialists_fukushima, 2011, 'Nuclear Energy', 'Fukushima nuclear disaster', specialists_nuclear_energy)

# %%
plot_trajectory_1d_specialists(df_specialists_migration, 2016, 'Migration', 'Cologne NYE', specialists_migration)

# %% [markdown]
# **Specialist MPs.** One line per party, following the MP with the most speeches on the topic who also
# spoke in the event year; markers are coloured by the MP's party in that year, so a switch shows up as a
# colour change (Gehrcke and Bulling-Schröter each appear as PDS and LINKE). The series turns at
# the event year only in rare cases (e.g. SPD for terrorism and CDU/CSU for financial politics)
#
# Two things not to over-read: the PCA is refitted on the specialists' own embeddings, so PC1 here is not
# the PC1 of the plots above, and a long straight segment is a gap in an MP's parliamentary presence
# rather than a gradual move — Hohmann's line from 2001 to 2018 in the terror panel is the clearest case.

# %% [markdown]
# ### 2.3 Cosine Similarity

# %%
def compute_distance_series(df, topic):
    """
    Aggregates the (already topic-filtered) speeches by party and year,
    then computes the cosine distance between each party's embedding
    in consecutive years.
    """
    df_agg = aggregate_by_party_year(df)
    df_agg = df_agg.sort_values(["party", "year"])

    records = []
    for party, color in party_colors.items():
        subset = df_agg[df_agg["party"] == party].sort_values("year")
        if len(subset) < 2:
            continue

        embeddings = np.stack(subset["embedding"])
        years = subset["year"].values

        for i in range(1, len(embeddings)):
            sim = cosine_similarity(embeddings[i-1].reshape(1, -1), embeddings[i].reshape(1, -1))[0, 0]
            distance = 1 - sim
            records.append({
                "party": party,
                "year": years[i],
                "distance": distance
            })

    return pd.DataFrame(records)

def plot_distance_series(df, topic, crisis, event_year):
    df_dist = compute_distance_series(df, topic)

    fig, ax = plt.subplots()

    for party, color in party_colors.items():
        subset = df_dist[df_dist["party"] == party]

        # skip parties with no distance value in the event year itself
        if event_year not in subset["year"].values:
            continue

        ax.plot(subset["year"], subset["distance"], color=color, label=party, marker='o', markersize=3)

    ax.axvline(event_year, color="grey", linestyle="--", linewidth=1)
    ax.annotate(crisis, (event_year, ax.get_ylim()[1]), xytext=(3, -10),
                textcoords="offset points", fontsize=8, color="0.2")

    ax.set_xlabel("Year")
    ax.set_ylabel("Cosine Distance to Previous Year")
    ax.legend(loc="upper left", bbox_to_anchor=(1.02, 1))
    ax.set_title(f"Year-over-Year Embedding Distance ({topic})")
    ax.set_xticks(sorted(df_dist["year"].unique()))
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    return df_dist

# %% [markdown]
# There's no distance value for 2001 itself, because we're looking at year-over-year change. So the first value is for 2002. Therefor we leave out the 9/11 terror attacks for this part of the analysis.

# %%
df_dist_finance = plot_distance_series(df_financial_crisis, "Financial Politics", 'Lehman Brothers collapse', 2008)
df_dist_finance
# Out:
#        party  year  distance
# 0    CDU/CSU  2001  0.004822
# 1    CDU/CSU  2002  0.005717
# 2    CDU/CSU  2003  0.005773
# 3    CDU/CSU  2004  0.002999
# 4    CDU/CSU  2005  0.008363
# ..       ...   ...       ...
# 98     LINKE  2019  0.014059
# 99     LINKE  2020  0.013920
# 100    LINKE  2021  0.008098
# 101      PDS  2001  0.011105
# 102      PDS  2002  0.008088
#
# [103 rows x 3 columns]

# %% [markdown]
# The peaks in 2008 is rather small, much smaller than the ones in 2018. The one large excursion is the FDP's 2017–2018 peak,
# which is the distance measured across its absence from parliament, not a shift in position.

# %%
df_dist_fukushima = plot_distance_series(df_fukushima, "Nuclear Energy", 'Fukushima nuclear disaster', 2011)
df_dist_fukushima
# Out:
#        party  year  distance
# 0    CDU/CSU  2001  0.005191
# 1    CDU/CSU  2002  0.008731
# 2    CDU/CSU  2003  0.007118
# 3    CDU/CSU  2004  0.003851
# 4    CDU/CSU  2005  0.003903
# ..       ...   ...       ...
# 98     LINKE  2019  0.004884
# 99     LINKE  2020  0.004670
# 100    LINKE  2021  0.008648
# 101      PDS  2001  0.008589
# 102      PDS  2002  0.012201
#
# [103 rows x 3 columns]

# %% [markdown]
# 2011 is the lowest point of the entire series for every party, at roughly 0.003–0.005. The year of the
# disaster is the year in which the parties' average climate-and-nuclear language changed least. The FDP
# peak in 2017/2018 is again the parliamentary gap.

# %%
df_dist_migration = plot_distance_series(df_migration, "Migration", 'Cologne NYE', 2016)
df_dist_migration
# Out:
#        party  year  distance
# 0    CDU/CSU  2001  0.009273
# 1    CDU/CSU  2002  0.020067
# 2    CDU/CSU  2003  0.023427
# 3    CDU/CSU  2004  0.019414
# 4    CDU/CSU  2005  0.014494
# ..       ...   ...       ...
# 97     LINKE  2019  0.011291
# 98     LINKE  2020  0.019091
# 99     LINKE  2021  0.032735
# 100      PDS  2001  0.020618
# 101      PDS  2002  0.044061
#
# [102 rows x 3 columns]

# %% [markdown]
# The minimum is 2016, immediately after the Cologne New Year's Eve, with every party at about 0.005–0.009.

# %% [markdown]
# ## 3. Party anchors — positions on an anchored axis
#
# Part 2 asked where PCA puts the parties, and found that the dominant direction tracks era and
# government/opposition rather than policy. This part replaces that with an axis we choose: two
# parties are named as poles, and everyone else is projected onto the line between them.
# Sample sizes behind these points are shown by marker size.
#
# - yearly mean is subtracted so a drift shared by all parties cannot look like movement;
# - the axis is estimated on the years before the event so the ruler does not move with the data; and the result is rescaled so the two anchor parties sit at 0 and 1 in that reference period, which makes a value of 0.4 readable as "40% of the way from one party's position to the other's"

# %%
def positions(topic_names, left, right, ref_years):
    "Party-year positions on the left->right axis, rescaled so left=0 and right=1 before the event."
    d = df[df.topic_emb_full_name.isin(topic_names)]

    # 1. aggregate to party-year, no threshold
    py = pd.DataFrame([dict(party=p, year=y, n=len(g),
                            E=np.mean(np.stack(g.E.to_numpy()), axis=0))
                       for (p, y), g in d.groupby(["party", "year"])])

    # a year with one party is useless: the yearly mean is that party, so demeaning gives 0
    per_year = py.groupby("year").size()
    lonely = per_year[per_year < 2].index.tolist()
    if lonely:
        print(f"years with only one party, dropped: {lonely}")
        py = py[~py.year.isin(lonely)]

    # 2. subtract the yearly mean
    ymu = {y: np.mean(np.stack(g.E.to_numpy()), axis=0) for y, g in py.groupby("year")}
    py["Ed"] = [e - ymu[y] for e, y in zip(py.E, py.year)]

    # 3. axis from the reference (pre-event) years only
    ref = py[py.year.isin(ref_years)]
    for anchor in (left, right):
        if not (ref.party == anchor).any():
            raise ValueError(f"{anchor} has no speech in the reference years {list(ref_years)}")
    a = (np.mean(np.stack(ref.loc[ref.party == right, "Ed"].to_numpy()), axis=0)
         - np.mean(np.stack(ref.loc[ref.party == left,  "Ed"].to_numpy()), axis=0))
    axis = a / np.linalg.norm(a)

    # 4. project, then rescale so the anchors sit at 0 and 1 in the reference period
    py["raw"] = [float(e @ axis) for e in py.Ed]
    lo = py.loc[py.year.isin(ref_years) & (py.party == left),  "raw"].mean()
    hi = py.loc[py.year.isin(ref_years) & (py.party == right), "raw"].mean()
    py["pos"] = (py.raw - lo) / (hi - lo)
    return py.sort_values(["party", "year"])


def plot_positions(py, event_year, left, right, title):
    fig, ax = plt.subplots(figsize=(9.5, 4.6))
    ax.axhline(0, color=PARTY_COLORS.get(left, "0.4"), ls=":", lw=1.4)
    ax.axhline(1, color=PARTY_COLORS.get(right, "0.4"), ls=":", lw=1.4)
    ax.axvline(event_year, color="#c0392b", ls="--", lw=1.5)
    for p, g in py.groupby("party"):
        g = g.sort_values("year")
        col = PARTY_COLORS.get(p, "grey")
        # break the line where a year is missing, so a gap is not drawn as a smooth move
        run = []
        for r in g.itertuples():
            if run and r.year - run[-1][0] > 1:
                ax.plot(*zip(*run), "-", color=col, lw=1.8)
                run = []
            run.append((r.year, r.pos))
        if len(run) > 1:
            ax.plot(*zip(*run), "-", color=col, lw=1.8)
        # marker size shows how many speeches are behind the point
        ax.scatter(g.year, g.pos, s=6 + 1.6 * g.n, color=col, zorder=4, label=p,
                   edgecolor="white", linewidth=.6)
    ax.set_xlabel("year")
    ax.set_ylabel(f"position on the {left} → {right} axis\n(0 = {left}, 1 = {right} before the event)")
    ax.set_title(title + "   (marker size = speeches behind the point)", loc="left", fontsize=10)
    ax.legend(fontsize=8, bbox_to_anchor=(1.01, 1), loc="upper left")
    plt.tight_layout()
    return ax

# %% [markdown]
# #### Fukushima — did the Union move toward the Greens?
#
# The clearest test case, because the answer is documented outside the corpus: after March 2011
# the CDU/CSU reversed course and legislated the nuclear phase-out it had extended only months
# earlier. If the embeddings carry policy content, the Union should move upward after 2011. The
# axis is estimated on 2005–2010.

# %%
NUCLEAR = TOPICS_FUKUSHIMA

py_nuc = positions(NUCLEAR, left="CDU/CSU", right="Grüne", ref_years=range(2005, 2011))
print("speeches per party-year:")
print(py_nuc.pivot(index="year", columns="party", values="n").fillna(0).astype(int).to_string())

plot_positions(py_nuc, 2011, "CDU/CSU", "Grüne", "Nuclear topics — CDU/CSU vs Grüne")
plt.savefig("fig_fukushima.png", dpi=150, bbox_inches="tight"); plt.show()

before = py_nuc[py_nuc.year.between(2007, 2010)].groupby("party").pos.mean()
after  = py_nuc[py_nuc.year.between(2012, 2015)].groupby("party").pos.mean()
print(pd.DataFrame({"2007-2010": before, "2012-2015": after,
                    "shift": after - before}).round(2).to_string())
# Out:
# speeches per party-year:
# party  AfD  CDU/CSU  FDP  Grüne  LINKE  PDS  SPD
# year
# 2000     0      181   67     76      0   57  139
# 2001     0       93   43     55      0   36   85
# 2002     0       60   35     32      0   27   63
# 2003     0       87   37     40      0    0   58
# 2004     0      120   53     60      0    0   81
# 2005     0       88   33     40      4    0   56
# 2006     0       62   40     96     50    0   67
# 2007     0      100   81    120     73    0  101
# 2008     0       95   60    142     74    0   99
# 2009     0       82   58     99     66    0   72
# 2010     0      155   96    182     99    0  156
# 2011     0      152   95    151    121    0  145
# 2012     0      110   75    123    102    0  129
# 2013     0      100   52    136     88    0  102
# 2014     0      113    0    179     75    0   86
# 2015     0      104    0    210     76    0   85
# 2016     0      107    0    154     90    0   80
# 2017     5       63    2    110     58    0   32
# 2018    99      114   59    139     80    0   85
# 2019   119      179   85    148     90    0  125
# 2020   104      156   65    132     93    0  117
# 2021    62       56   29     50     33    0   51
#          2007-2010  2012-2015  shift
# party
# CDU/CSU      -0.04      -0.12  -0.08
# FDP           0.36       0.11  -0.25
# Grüne         1.13       1.14   0.01
# LINKE         0.76       0.67  -0.09
# SPD           0.12       0.34   0.22

# %% [markdown]
# *Interpretation.* From 2006 on the ordering is stable and mostly plausible: Grüne and LINKE at one end, CDU/CSU at the other (only the positions of SPD and FDP up until 2009 are the opposite of what one would expect). So the axis does separate the parties.
#
# The hypothesis still fails. Between 2007–2010 and 2012–2015 the CDU/CSU moves *away* from the Greens
# (−0.04 → −0.12) and the Grüne stay where they are (1.13 → 1.14). The only clear moves are the SPD
# upward (0.12 → 0.34) and the FDP downward (0.36 → 0.11) — and both parties changed government status in
# exactly that window, which points at an opposition-versus-government register rather than a position on
# nuclear power. Note also that the FDP's later average rests on 2012 and 2013 alone, since it was out of
# parliament from 2014.

# %% [markdown]
# #### Migration — where do the parties sit relative to the AfD?
#
# The AfD only enters the Bundestag in 2017, so the axis has to be estimated *after* the event
# rather than before it. That weakens the reading considerably: we can see the ordering of the
# parties from 2017 onward, but not how they stood relative to a party that did not yet exist.
#
# Anchors: Grüne und AfD

# %%
MIGRATION = TOPICS_MIGRATION

py_mig = positions(MIGRATION, left="Grüne", right="AfD", ref_years=range(2018, 2022))
print("speeches per party-year:")
print(py_mig.pivot(index="year", columns="party", values="n").fillna(0).astype(int).to_string())

plot_positions(py_mig, 2016, "Grüne", "AfD", "Migration topic — Grüne vs AfD")
plt.savefig("fig_migration.png", dpi=150, bbox_inches="tight"); plt.show()
# Out:
# speeches per party-year:
# party  AfD  CDU/CSU  FDP  Grüne  LINKE  PDS  SPD
# year
# 2000     0       31   23     20      0   17   29
# 2001     0       23    4      9      0    7   16
# 2002     0       10    2      8      0    4    4
# 2003     0       36    7      7      0    0   17
# 2004     0       30    9      9      0    0   12
# 2005     0       10    3      7      0    0   10
# 2006     0       14    7     12     16    0   10
# 2007     0       17   11     18     32    0   18
# 2008     0       15    8     22     18    0   22
# 2009     0       15   14     17     12    0   12
# 2010     0       29   15     18     24    0   13
# 2011     0       35   21     29     18    0   22
# 2012     0       19   19     23     16    0   18
# 2013     0       28   15     20     23    0   16
# 2014     0       36    0     45     31    0   37
# 2015     0       93    0     76     50    0   47
# 2016     0       74    0     69     44    0   43
# 2017     7       25    7     22     14    0   14
# 2018    69       97   39     37     29    0   53
# 2019    42       50   20     29     26    0   39
# 2020    31       36   14     13     20    0   27
# 2021     8        6    6      4      4    0    6

# %% [markdown]
# *Interpretation.* The AfD separates cleanly from 2018 (0.87–1.26, its 2017 point of about 0.6 rests on
# seven speeches), while every other party stays between 0.1 and 0.6. Before 2017 the parties are bunched
# at 0.2–0.6 with no stable ordering between them, so the axis has not found a migration-policy scale on
# which the house can be ranked — it has found "AfD language versus everyone else". By this measure the
# CDU/CSU is no closer to the AfD than the SPD is.
#
# The 2021 values are stubs: the electoral term ends in September, and the Grüne's drop to −0.41 rests on
# four speeches.

# %% [markdown]
# ## 4. Topic frequencies
#
# Does an event change how much is said about a topic at all? This part never touches the embedding
# vectors — only the topic labels and the speech counts behind them.

# %%
EVENTS = [
    #Afghanistan topics stand in for 9/11, since corpus records the parliamentary consequences rather than the attack
    dict(date="2001-09-11", label="9/11 terror attacks", kind="crisis", topics=TOPICS_9_11),
    dict(date="2008-09-15", label="Lehman collapse / financial crisis", kind="crisis", topics=TOPICS_FINANCE),
    dict(date="2011-03-11", label="Fukushima nuclear disaster", kind="crisis", topics=TOPICS_FUKUSHIMA),
    dict(date="2016-01-01", label="Migration scepticism (post-Cologne NYE)", kind="crisis", topics=TOPICS_MIGRATION),
]

for ev in EVENTS:
    ev["year"] = int(ev["date"][:4])
#checks that every name still exists in the data, so a re-run of the topic model would raise an error rather than silently analysing nothing.
unknown = {t for ev in EVENTS for t in ev["topics"]} - set(ALL_TOPICS)
if unknown:
    raise ValueError(f"topic name(s) not found in the data: {unknown}")
print("all topic names found in the data\n")

for ev in EVENTS:
    n = df.topic_emb_full_name.isin(ev["topics"]).sum()
    print(f"{ev['date']}  {ev['label']}")
    for t in ev["topics"]:
        print(f"     - {t}")
    print(f"     {n:,} speeches in total\n")
# Out:
# all topic names found in the data
#
# 2001-09-11  9/11 terror attacks
#      - Verteidigungspolitik und Bundeswehr
#      5,461 speeches in total
#
# 2008-09-15  Lehman collapse / financial crisis
#      - Steuern und Finanzpolitik
#      6,895 speeches in total
#
# 2011-03-11  Fukushima nuclear disaster
#      - Umweltschutz, Klimapolitik und Atomkraft
#      9,711 speeches in total
#
# 2016-01-01  Migration scepticism (post-Cologne NYE)
#      - Migration, Asyl und Einwanderung
#      2,534 speeches in total

# %% [markdown]
# The zero-shot categories are much larger than the BERTopic topics of the twin notebook: **5,461**
# speeches behind 9/11 (defence policy), **6,895** behind Lehman (taxes and finance), **9,711** behind
# Fukushima (environment, climate and nuclear power) and **2,534** behind migration. Only the migration
# category is comparable in size to its BERTopic counterpart. The other three pool a great deal of debate
# that has nothing to do with the event, which damps any event-specific signal in the frequency curves
# below.

# %% [markdown]
# ### Does attention change around the event?
#
# Two views per event.
#
# **Attention over time.** The share of all speeches in a year that fall on the
# event's topics. If a crisis reorganises the agenda, this is where it shows up most directly.
#
# **Who is doing the talking.** For each party, the share of *its own* speeches
# devoted to those topics, in the three years before and the three years after the event. Using
# each party's own denominator means a party that simply speaks more often does not appear more
# interested.
#
# **Share of each party's speeches on topic**

# %%
WINDOW = 3      # years before / after the event used for the party comparison

def frequency_figure(ev):
    "Attention to an event's topics: over time, and per party before vs after."
    on_topic = df.topic_emb_full_name.isin(ev["topics"])
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 3.8),
                                   gridspec_kw={"width_ratios": [1.5, 1]})

    # --- left: share of the year's speeches, one line per topic plus the total
    for t in ev["topics"]:
        share = df.topic_emb_full_name.eq(t).groupby(df.year).mean()
        ax1.plot(share.index, 100 * share.values, lw=1.4, alpha=.75,
                 label=t.split("/")[0])
    if len(ev["topics"]) > 1:
        tot = on_topic.groupby(df.year).mean()
        ax1.plot(tot.index, 100 * tot.values, lw=2.4, color="0.2", label="all topics together")
    ax1.axvline(ev["year"], color="#c0392b", ls="--", lw=1.5)
    ax1.set_xlabel("year"); ax1.set_ylabel("% of that year's speeches")
    ax1.set_title(f"{ev['label']} ({ev['year']})", loc="left", fontsize=10)
    ax1.legend(fontsize=7)

    # --- right: per party, share of its own speeches, before vs after
    pre  = df[df.year.between(ev["year"] - WINDOW, ev["year"] - 1)]
    post = df[df.year.between(ev["year"] + 1, ev["year"] + WINDOW)]
    parties = [p for p in PARTY_COLORS if p in set(pre.party) | set(post.party)]
    b = [100 * pre.loc[pre.party == p, "topic_emb_full_name"].isin(ev["topics"]).mean()
         for p in parties]
    a = [100 * post.loc[post.party == p, "topic_emb_full_name"].isin(ev["topics"]).mean()
         for p in parties]
    x = np.arange(len(parties))
    ax2.bar(x - 0.2, b, 0.4, color="0.75", label=f"{WINDOW}y before")
    ax2.bar(x + 0.2, a, 0.4, color=[PARTY_COLORS[p] for p in parties], label=f"{WINDOW}y after")
    ax2.set_xticks(x); ax2.set_xticklabels(parties, rotation=30, ha="right", fontsize=8)
    ax2.set_ylabel("% of the party's speeches")
    ax2.set_title("attention per party", loc="left", fontsize=10)
    ax2.legend(fontsize=7)

    plt.tight_layout()
    slug = "".join(ch if ch.isalnum() else "_" for ch in ev["label"].lower())[:28]
    plt.savefig(f"fig_freq_{ev['year']}_{slug}.png", dpi=150, bbox_inches="tight")
    plt.show()

    # --- the same numbers as a table: party x topic, share of the party's speeches
    d = df[on_topic]
    tab = (100 * pd.crosstab(d.party, d.topic_emb_full_name).div(
           df.groupby("party").size(), axis=0)).round(2)
    tab.columns = [c.split("/")[0][:22] for c in tab.columns]
    print(f"share of each party's speeches on these topics, % — {ev['label']}")
    print(tab.to_string(), "\n")
    return tab


for ev in EVENTS:
    frequency_figure(ev)
# Out:
# share of each party's speeches on these topics, % — 9/11 terror attacks
#          Verteidigungspolitik u
# party
# AfD                        6.37
# CDU/CSU                    6.40
# FDP                        6.67
# Grüne                      6.90
# LINKE                      7.60
# PDS                        9.66
# SPD                        6.13
# share of each party's speeches on these topics, % — Lehman collapse / financial crisis
#          Steuern und Finanzpoli
# party
# AfD                        7.05
# CDU/CSU                    8.59
# FDP                       11.42
# Grüne                      7.10
# LINKE                      7.18
# PDS                        7.57
# SPD                        8.54
# share of each party's speeches on these topics, % — Fukushima nuclear disaster
#          Umweltschutz, Klimapol
# party
# AfD                       14.75
# CDU/CSU                    9.89
# FDP                       10.26
# Grüne                     16.64
# LINKE                     11.74
# PDS                       10.94
# SPD                       11.15
# share of each party's speeches on these topics, % — Migration scepticism (post-Cologne NYE)
#          Migration, Asyl und Ei
# party
# AfD                        5.95
# CDU/CSU                    3.03
# FDP                        2.35
# Grüne                      3.46
# LINKE                      3.48
# PDS                        2.55
# SPD                        2.68

# %% [markdown]
# *Interpretation.* With categories this coarse, only two of the four events are visible in the attention
# curves.
#
# **9/11 is the clearest.** Defence policy jumps from 5.6% of all speeches in 2000 to 9.2% in 2001 — the
# highest value of the whole series — then settles back into a 5–8% oscillation for two decades. Every
# party rises in the three years after: CDU/CSU 4.8 → 7.9%, SPD 5.4 → 6.7%, Grüne 5.7 → 6.5%, FDP 7.4 →
# 7.7%. The PDS bar (6.4 → 14.5%) should be ignored: after 2002 the party held only two direct mandates,
# so the denominator is a handful of speeches.
#
# **Lehman is muted.** Attention runs at 10.4% in 2008 and peaks at 13.3% in 2009, but 2003 already
# reached 13.0%, so the crisis peak is not exceptional for a category that also contains every budget and
# tax debate. The party bars move by roughly one point each. What is striking is the decline afterwards,
# to below 5% by 2015–2017.
#
# **Fukushima does not register at all.** The category peaks at 14.3% in 2010, the year *before* the
# disaster, and *falls* to 13.6% in 2011. The all-time high is 2019 (15.5%) — the climate debate, not the
# reactor. The Grüne, who own the category (16.6% of their speeches over the whole period, against 9.9%
# for the CDU/CSU), actually go *down* from 18.2% to 15.9% after the event.
#
# **Migration behaves as in the BERTopic version.** The series peaks in 2015 (6.7%), a year before the
# Cologne New Year's Eve that dates the event, dips to 3.6% in 2017 and reaches a second peak of 6.75% in
# 2018. The AfD is the clear owner — 5.95% of its speeches over the period and 7.9% in its first three
# years in parliament — while the others sit between 2.4% and 3.5%.
#
# One caveat on the tables: they cover the whole 2000–2021 period, so they describe a party's general
# profile on the category rather than its behaviour around the event. The bars in the right panel are the
# ones restricted to the ±3-year windows.
